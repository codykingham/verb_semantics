# %% [markdown]
# # Context Selection Development
#
# **TODO 10.03.18**
#
# Currently the algorithm excludes phrase atoms that begin with the direct object marker. This is a problem, of course, for Objc function phrases. `is_preposition_subj` should be rewritten to check for valid phrase types. This may be tricky since not all את markers will be functioning as an object marker. So: fixing this requires first an exploration of the subphrase relation codes or phrase atom relations that can occur with את. I'm assuming that the specification relation will communicate an adjectival, rather than grammatical, force.
#
# This gets even trickier when nouns in the object phrase are marked by markers other than את. I should see whether this happens, and if it does, can a workaround be built with the relation features.

# %%
# First, I load the necesssary modules, data, and helper functions.
import collections
from tf.fabric import Fabric
from functions.helpers import show_results, filter_results

# load BHSA data into TF
TF = Fabric(locations='~/github/etcbc/bhsa/tf', modules='c', silent=True)
api = TF.load('''
                book chapter verse
                function sp pdp mother
                rela typ lex
              ''', silent=True)
api.makeAvailableIn(globals()) # globalize TF methods

# %%
def is_preposition_subj(word):
    '''
    Return boolean on whether a word is a preposition subject,
    necessary for cases in which the subject is marked in
    a prepositional phrase, such as in passive clauses.
    Require a word node.
    
    *Caution*
    Does not capture cases such as Gen 21:5 (ca# 516487)
    '''
    # get word phrase
    w_phrase = L.u(word, otype='phrase')[0]
    
    # get all phrase atoms in the phrase    
    # exclude negations and conjunctions
    phrase_atoms = [phrs_at for phrs_at in L.d(w_phrase, otype='phrase_atom')
                        if F.typ.v(phrs_at) not in {'NegP','CP'}
                   ]
    
    # check whether the only phrase atom in the phrase is a prep. phrase
    if len(phrase_atoms) == 1 and F.typ.v(phrase_atoms[0]) == 'PP':
        
        # is a prepositional subject
        return True

    else:
        # is not a prep subj
        return False

def get_KL_head(KL_wordnode, good_pdp, good_sp):
    '''
    Extract the head noun in a כֹל construct chain.
    The function simply returns the first substantive in the chain.
    '''
    
    rectum = E.mother.t(KL_wordnode) # get rectum subphrase
    KL_phrase = L.d(L.u(KL_wordnode, 'phrase')[0], 'word') # for phrase boundary
    
    if not rectum:
        return False  # KL not in norm. construct (e.g. w/ verbs)
    
    # get words and nouns in the rectum subphrase
    r_words = L.d(rectum[0], 'word')
    r_nouns = [w for w in r_words 
               if F.sp.v(w) in good_sp
               and F.pdp.v(w) in good_pdp
               and w in KL_phrase
              ]
    
    if r_nouns:
        return r_nouns[0] # return the first noun
    else:
        return None # no noun found, return nothing
    
    
def get_heads(phrase):
    '''
    Returns substantive head nouns, if there are any, from a phrase node.
    "substantive" does not include prounouns.
    
    Based on a supplied phrase get phrase atom and subphrase features 
    and compare them against a group of sets.
    Define those sets first. Then make the comparison.
    
    *Caution* 
    This function works reasonably well,
    but there are a number of edge cases that it does not catch.
    Fine-tuning this function would make a nice notebook in itself.
    See Gen 20:5 for a good edge case example, in which both היא pronouns
    are registered as subjects, but only one should be.
    '''
    
    good_sp = {'subs', 'nmpr', 'adjv'}
    good_pdp = {'subs', 'nmpr'}

    # exclude words in phrase_atoms with these relation features
    omit_pa_rela = {'Appo', # apposition
                    'Spec'} # specification
    
    # exclude words in subphrases with these relation features
    omit_sp_rela = {'rec', # nomen rectum
                    'adj', # adjunct 
                    'atr', # attributive
                    'mod', # modifier
                    'dem'} # demontrative
        
    heads = [] # nouns go here
    phrase_words = L.d(phrase, 'word')
        
    for word in phrase_words:
        
        # get phrases's phrase atoms, subphrases, and subphrase relations
        phrase_atom = L.u(word, 'phrase_atom')[0]
        subphrases = L.u(word, 'subphrase') 
        sp_relas = set(F.rela.v(sp) for sp in subphrases)

        # compare word/phrase features
        if all([
                F.pdp.v(word) in good_sp, # is noun
                F.sp.v(word) in good_pdp, # is noun
                F.typ.v(phrase_atom) == 'NP' or is_preposition_subj(word), # is noun phrase or prep. subj.
                F.rela.v(phrase_atom) not in omit_pa_rela, # is valid hrase_atom rela.
                not sp_relas & omit_sp_rela, # is valid subphrase rela.
               ]):
        
            # handle כֹל constructs by retrieving their noun:
            if F.lex.v(word) == 'KL/':
                KL_head = get_KL_head(word, good_pdp, good_sp) # returns word node or None
                if KL_head:
                    heads.append(KL_head) # כֹל + noun found
                else:
                    continue # no noun found, skip it
            else:
                heads.append(word) # word is a head
    
        else:
            continue
            
    return heads

# %%
results = []
ct = 0

for phrase in F.function.s('Objc'):
    
    heads = get_heads(phrase)
    
    if heads and len(heads) < len(L.d(phrase, 'word')):
        
        print(T.sectionFromNode(phrase))
        print(T.text(L.d(L.u(phrase, 'clause')[0], 'word')))
        print(phrase)
        print(T.text(L.d(phrase, 'word')))
        heads = [T.text([head]) for head in heads]
        print(' | '.join(heads))
        print()
        
        ct += 1
        
        if ct == 100:
            break
# Out:
# ('Genesis', 1, 1)
# בְּרֵאשִׁ֖ית בָּרָ֣א אֱלֹהִ֑ים אֵ֥ת הַשָּׁמַ֖יִם וְאֵ֥ת הָאָֽרֶץ׃
# 651506
# אֵ֥ת הַשָּׁמַ֖יִם וְאֵ֥ת הָאָֽרֶץ׃
# שָּׁמַ֖יִם  | אָֽרֶץ׃
#
# ('Genesis', 1, 4)
# וַיַּ֧רְא אֱלֹהִ֛ים אֶת־הָאֹ֖ור
# 651529
# אֶת־הָאֹ֖ור
# אֹ֖ור
#
# ('Genesis', 1, 7)
# וַיַּ֣עַשׂ אֱלֹהִים֮ אֶת־הָרָקִיעַ֒
# 651565
# אֶת־הָרָקִיעַ֒
# רָקִיעַ֒
#
# ('Genesis', 1, 11)
# תַּֽדְשֵׁ֤א הָאָ֨רֶץ֙ דֶּ֔שֶׁא עֵ֚שֶׂב עֵ֣ץ פְּרִ֞י
# 651619
# דֶּ֔שֶׁא עֵ֚שֶׂב עֵ֣ץ פְּרִ֞י
# דֶּ֔שֶׁא  | עֵ֚שֶׂב  | עֵ֣ץ
#
# ('Genesis', 1, 12)
# וַתֹּוצֵ֨א הָאָ֜רֶץ דֶּ֠שֶׁא עֵ֣שֶׂב וְעֵ֧ץ
# 651635
# דֶּ֠שֶׁא עֵ֣שֶׂב וְעֵ֧ץ
# דֶּ֠שֶׁא  | עֵ֣שֶׂב  | עֵ֧ץ
#
# ('Genesis', 1, 20)
# יִשְׁרְצ֣וּ הַמַּ֔יִם שֶׁ֖רֶץ נֶ֣פֶשׁ חַיָּ֑ה
# 651711
# שֶׁ֖רֶץ נֶ֣פֶשׁ חַיָּ֑ה
# שֶׁ֖רֶץ
#
# ('Genesis', 1, 21)
# וַיִּבְרָ֣א אֱלֹהִ֔ים אֶת־הַתַּנִּינִ֖ם הַגְּדֹלִ֑ים וְאֵ֣ת כָּל־נֶ֣פֶשׁ לְמִֽינֵהֶ֗ם
# 651719
# אֶת־הַתַּנִּינִ֖ם הַגְּדֹלִ֑ים וְאֵ֣ת כָּל־נֶ֣פֶשׁ
# תַּנִּינִ֖ם  | נֶ֣פֶשׁ
#
# ('Genesis', 1, 21)
# וְאֵ֨ת כָּל־עֹ֤וף כָּנָף֙ לְמִינֵ֔הוּ
# 651729
# אֵ֨ת כָּל־עֹ֤וף כָּנָף֙
# עֹ֤וף
#
# ('Genesis', 1, 24)
# תֹּוצֵ֨א הָאָ֜רֶץ נֶ֤פֶשׁ חַיָּה֙ לְמִינָ֔הּ
# 651763
# נֶ֤פֶשׁ חַיָּה֙
# נֶ֤פֶשׁ
#
# ('Genesis', 1, 24)
# בְּהֵמָ֥ה וָרֶ֛מֶשׂ וְחַֽיְתֹו־אֶ֖רֶץ לְמִינָ֑הּ
# 651765
# בְּהֵמָ֥ה וָרֶ֛מֶשׂ וְחַֽיְתֹו־אֶ֖רֶץ
# בְּהֵמָ֥ה  | רֶ֛מֶשׂ  | חַֽיְתֹו־
#
# ('Genesis', 1, 25)
# וַיַּ֣עַשׂ אֱלֹהִים֩ אֶת־חַיַּ֨ת הָאָ֜רֶץ לְמִינָ֗הּ
# 651773
# אֶת־חַיַּ֨ת הָאָ֜רֶץ
# חַיַּ֨ת
#
# ('Genesis', 1, 25)
# וְאֶת־הַבְּהֵמָה֙ לְמִינָ֔הּ
# 651776
# אֶת־הַבְּהֵמָה֙
# בְּהֵמָה֙
#
# ('Genesis', 1, 25)
# וְאֵ֛ת כָּל־רֶ֥מֶשׂ הָֽאֲדָמָ֖ה לְמִינֵ֑הוּ
# 651779
# אֵ֛ת כָּל־רֶ֥מֶשׂ הָֽאֲדָמָ֖ה
# רֶ֥מֶשׂ
#
# ('Genesis', 1, 27)
# וַיִּבְרָ֨א אֱלֹהִ֤ים׀ אֶת־הָֽאָדָם֙ בְּצַלְמֹ֔ו
# 651802
# אֶת־הָֽאָדָם֙
# אָדָם֙
#
# ('Genesis', 1, 28)
# וּמִלְא֥וּ אֶת־הָאָ֖רֶץ
# 651823
# אֶת־הָאָ֖רֶץ
# אָ֖רֶץ
#
# ('Genesis', 1, 30)
# וּֽלְכָל־חַיַּ֣ת הָ֠אָרֶץ וּלְכָל־עֹ֨וף הַשָּׁמַ֜יִם וּלְכֹ֣ל׀ רֹומֵ֣שׂ עַל־הָאָ֗רֶץ אֶת־כָּל־יֶ֥רֶק עֵ֖שֶׂב לְאָכְלָ֑ה
# 651856
# אֶת־כָּל־יֶ֥רֶק עֵ֖שֶׂב
# יֶ֥רֶק
#
# ('Genesis', 2, 3)
# וַיְבָ֤רֶךְ אֱלֹהִים֙ אֶת־יֹ֣ום הַשְּׁבִיעִ֔י
# 651897
# אֶת־יֹ֣ום הַשְּׁבִיעִ֔י
# יֹ֣ום
#
# ('Genesis', 2, 4)
# עֲשֹׂ֛ות יְהוָ֥ה אֱלֹהִ֖ים אֶ֥רֶץ וְשָׁמָֽיִם׃
# 651915
# אֶ֥רֶץ וְשָׁמָֽיִם׃
# אֶ֥רֶץ  | שָׁמָֽיִם׃
#
# ('Genesis', 2, 5)
# לַֽעֲבֹ֖ד אֶת־הָֽאֲדָמָֽה׃
# 651934
# אֶת־הָֽאֲדָמָֽה׃
# אֲדָמָֽה׃
#
# ('Genesis', 2, 6)
# וְהִשְׁקָ֖ה אֶֽת־כָּל־פְּנֵֽי־הָֽאֲדָמָֽה׃
# 651941
# אֶֽת־כָּל־פְּנֵֽי־הָֽאֲדָמָֽה׃
# פְּנֵֽי־
#
# ('Genesis', 2, 7)
# וַיִּיצֶר֩ יְהוָ֨ה אֱלֹהִ֜ים אֶת־הָֽאָדָ֗ם עָפָר֙ מִן־הָ֣אֲדָמָ֔ה
# 651945
# אֶת־הָֽאָדָ֗ם
# אָדָ֗ם
#
# ('Genesis', 2, 7)
# וַיִּפַּ֥ח בְּאַפָּ֖יו נִשְׁמַ֣ת חַיִּ֑ים
# 651950
# נִשְׁמַ֣ת חַיִּ֑ים
# נִשְׁמַ֣ת
#
# ('Genesis', 2, 8)
# וַיָּ֣שֶׂם שָׁ֔ם אֶת־הָֽאָדָ֖ם
# 651964
# אֶת־הָֽאָדָ֖ם
# אָדָ֖ם
#
# ('Genesis', 2, 9)
# וַיַּצְמַ֞ח יְהוָ֤ה אֱלֹהִים֙ מִן־הָ֣אֲדָמָ֔ה כָּל־עֵ֛ץ
# 651971
# כָּל־עֵ֛ץ
# עֵ֛ץ
#
# ('Genesis', 2, 9)
# וְעֵ֤ץ הַֽחַיִּים֙ בְּתֹ֣וךְ הַגָּ֔ן
# 651978
# עֵ֤ץ הַֽחַיִּים֙
# עֵ֤ץ
#
# ('Genesis', 2, 9)
# וְעֵ֕ץ הַדַּ֖עַת טֹ֥וב וָרָֽע׃
# 651981
# עֵ֕ץ הַדַּ֖עַת טֹ֥וב וָרָֽע׃
# עֵ֕ץ
#
# ('Genesis', 2, 10)
# לְהַשְׁקֹ֖ות אֶת־הַגָּ֑ן
# 651987
# אֶת־הַגָּ֑ן
# גָּ֑ן
#
# ('Genesis', 2, 11)
# הַסֹּבֵ֗ב אֵ֚ת כָּל־אֶ֣רֶץ הַֽחֲוִילָ֔ה
# 651999
# אֵ֚ת כָּל־אֶ֣רֶץ הַֽחֲוִילָ֔ה
# אֶ֣רֶץ
#
# ('Genesis', 2, 13)
# הַסֹּובֵ֔ב אֵ֖ת כָּל־אֶ֥רֶץ כּֽוּשׁ׃
# 652014
# אֵ֖ת כָּל־אֶ֥רֶץ כּֽוּשׁ׃
# אֶ֥רֶץ
#
# ('Genesis', 2, 15)
# וַיִּקַּ֛ח יְהוָ֥ה אֱלֹהִ֖ים אֶת־הָֽאָדָ֑ם
# 652029
# אֶת־הָֽאָדָ֑ם
# אָדָ֑ם
#
# ('Genesis', 2, 18)
# אֶֽעֱשֶׂהּ־לֹּ֥ו עֵ֖זֶר כְּנֶגְדֹּֽו׃
# 652065
# עֵ֖זֶר כְּנֶגְדֹּֽו׃
# עֵ֖זֶר
#
# ('Genesis', 2, 19)
# וַיִּצֶר֩ יְהוָ֨ה אֱלֹהִ֜
# וַיַּעַשׂ֩ יְהוָ֨ה אֱלֹהִ֜ים לְאָדָ֧ם וּלְאִשְׁתֹּ֛ו כָּתְנֹ֥ות עֹ֖ור
# 652423
# כָּתְנֹ֥ות עֹ֖ור
# כָּתְנֹ֥ות
#
# ('Genesis', 3, 23)
# לַֽעֲבֹד֙ אֶת־הָ֣אֲדָמָ֔ה
# 652453
# אֶת־הָ֣אֲדָמָ֔ה
# אֲדָמָ֔ה
#
# ('Genesis', 3, 24)
# וַיְגָ֖רֶשׁ אֶת־הָֽאָדָ֑ם
# 652459
# אֶת־הָֽאָדָ֑ם
# אָדָ֑ם
#
# ('Genesis', 3, 24)
# וַיַּשְׁכֵּן֩ מִקֶּ֨דֶם לְגַן־עֵ֜דֶן אֶת־הַכְּרֻבִ֗ים וְאֵ֨ת לַ֤הַט הַחֶ֨רֶב֙
# 652463
# אֶת־הַכְּרֻבִ֗ים וְאֵ֨ת לַ֤הַט הַחֶ֨רֶב֙
# כְּרֻבִ֗ים  | לַ֤הַט
#
# ('Genesis', 3, 24)
# לִשְׁמֹ֕ר אֶת־דֶּ֖רֶךְ עֵ֥ץ הַֽחַיִּֽים׃ ס
# 652467
# אֶת־דֶּ֖רֶךְ עֵ֥ץ הַֽחַיִּֽים׃ ס
# דֶּ֖רֶךְ
#
# ('Genesis', 4, 1)
# וַתֵּ֣לֶד אֶת־קַ֔יִן
# 652476
# אֶת־קַ֔יִן
# קַ֔יִן
#
# ('Genesis', 4, 11)
# אֲשֶׁ֣ר פָּצְתָ֣ה אֶת־פִּ֔יהָ
# 652595
# אֶת־פִּ֔יהָ
# פִּ֔יהָ
#
# ('Genesis', 4, 11)
# לָקַ֛חַת אֶת־דְּמֵ֥י אָחִ֖יךָ מִיָּדֶֽךָ׃
# 652597
# אֶת־דְּמֵ֥י אָחִ֖יךָ
# דְּמֵ֥י
#
# ('Genesis', 4, 12)
# כִּ֤י תַֽעֲבֹד֙ אֶת־הָ֣אֲדָמָ֔ה
# 652601
# אֶת־הָ֣אֲדָמָ֔ה
# אֲדָמָ֔ה
#
# ('Genesis', 4, 17)
# וַיֵּ֤דַע קַ֨יִן֙ אֶת־אִשְׁתֹּ֔ו
# 652662
# אֶת־אִשְׁתֹּ֔ו
# אִשְׁתֹּ֔ו
#
# ('Genesis', 4, 17)
# וַתֵּ֣לֶד אֶת־חֲנֹ֑וךְ
# 652667
# אֶת־חֲנֹ֑וךְ
# חֲנֹ֑וךְ
#
# ('Genesis', 4, 17)
# וַיִּקְרָא֙ שֵׁ֣ם הָעִ֔יר כְּשֵׁ֖ם בְּנֹ֥ו חֲנֹֽוךְ׃
# 652674
# שֵׁ֣ם הָעִ֔יר
# שֵׁ֣ם
#
# ('Genesis', 4, 18)
# וְעִירָ֕ד יָלַ֖ד אֶת־מְחֽוּיָאֵ֑ל
# 652683
# אֶת־מְחֽוּיָאֵ֑ל
# מְחֽוּיָאֵ֑ל
#
# ('Genesis', 4, 18)
# וּמְחִיּיָאֵ֗ל יָלַד֙ אֶת־מְת֣וּשָׁאֵ֔ל
# 652687
# אֶת־מְת֣וּשָׁאֵ֔ל
# מְת֣וּשָׁאֵ֔ל
#
# ('Genesis', 4, 18)
# וּמְתוּשָׁאֵ֖ל יָלַ֥ד אֶת־לָֽמֶךְ׃
# 652691
# אֶת־לָֽמֶךְ׃
# לָֽמֶךְ׃
#
# ('Genesis', 4, 19)
# וַיִּֽקַּֽח־לֹ֥ו לֶ֖מֶךְ שְׁתֵּ֣י נָשִׁ֑ים
# 652696
# שְׁתֵּ֣י נָשִׁ֑ים
# שְׁתֵּ֣י
#
# ('Genesis', 4, 20)
# וַתֵּ֥לֶד עָדָ֖ה אֶת־יָבָ֑ל
# 652705
# אֶת־יָבָ֑ל
# יָבָ֑ל
#
# ('Genesis', 4, 22)
# וְצִלָּ֣ה גַם־הִ֗וא יָֽלְדָה֙ אֶת־תּ֣וּבַל קַ֔יִן
# 652718
# אֶת־תּ֣וּבַל קַ֔יִן
# תּ֣וּבַל קַ֔יִן
#
# ('Genesis', 4, 25)
# וַיֵּ֨דַע אָדָ֥ם עֹוד֙ אֶת־אִשְׁתֹּ֔ו
# 652750
# אֶת־אִשְׁתֹּ֔ו
# אִשְׁתֹּ֔ו
#
# ('Genesis', 4, 25)
# וַתִּקְרָ֥א אֶת־שְׁמֹ֖ו שֵׁ֑ת
# 652756
# אֶת־שְׁמֹ֖ו
# שְׁמֹ֖ו
#
# ('Genesis', 4, 25)
# כִּ֣י שָֽׁת־לִ֤י אֱלֹהִים֙ זֶ֣רַע אַחֵ֔ר תַּ֣חַת הֶ֔בֶל
# 652762
# זֶ֣רַע אַחֵ֔ר
# זֶ֣רַע
#
# ('Genesis', 4, 26)
# וַיִּקְרָ֥א אֶת־שְׁמֹ֖ו אֱנֹ֑ושׁ
# 652773
# אֶת־שְׁמֹ֖ו
# שְׁמֹ֖ו
#
# ('Genesis', 5, 2)
# וַיִּקְרָ֤א אֶת־שְׁמָם֙ אָדָ֔ם בְּיֹ֖ום
# 652795
# אֶת־שְׁמָם֙
# שְׁמָם֙
#
# ('Genesis', 5, 3)
# וַיִּקְרָ֥א אֶת־שְׁמֹ֖ו שֵֽׁת׃
# 652809
# אֶת־שְׁמֹ֖ו
# שְׁמֹ֖ו
#
# ('Genesis', 5, 4)
# אַֽחֲרֵי֙ הֹולִידֹ֣ו אֶת־שֵׁ֔ת
# 652815
# אֶת־שֵׁ֔ת
# שֵׁ֔ת
#
# ('Genesis', 5, 4)
# וַיֹּ֥ולֶד בָּנִ֖ים וּבָנֹֽות׃
# 652819
# בָּנִ֖ים וּבָנֹֽות׃
# בָּנִ֖ים  | בָנֹֽות׃
#
# ('Genesis', 5, 6)
# וַיֹּ֖ולֶד אֶת־אֱנֹֽושׁ׃
# 652834
# אֶת־אֱנֹֽושׁ׃
# אֱנֹֽושׁ׃
#
# ('Genesis', 5, 7)
# אַֽחֲרֵי֙ הֹולִידֹ֣ו אֶת־אֱנֹ֔ושׁ
# 652839
# אֶת־אֱנֹ֔ושׁ
# אֱנֹ֔ושׁ
#
# ('Genesis', 5, 7)
# וַיֹּ֥ולֶד בָּנִ֖ים וּבָנֹֽות׃
# 652843
# בָּנִ֖ים וּבָנֹֽות׃
# בָּנִ֖ים  | בָנֹֽות׃
#
# ('Genesis', 5, 9)
# וַיֹּ֖ולֶד אֶת־קֵינָֽן׃
# 652856
# אֶת־קֵינָֽן׃
# קֵינָֽן׃
#
# ('Genesis', 5, 10)
# אַֽחֲרֵי֙ הֹולִידֹ֣ו אֶת־קֵינָ֔ן
# 652861
# אֶת־קֵינָ֔ן
# קֵינָ֔ן
#
# ('Genesis', 5, 10)
# וַיֹּ֥ולֶד בָּנִ֖ים וּבָנֹֽות׃
# 652865
# בָּנִ֖ים וּבָנֹֽות׃
# בָּנִ֖ים  | בָנֹֽות׃
#
# ('Genesis', 5,
# אֶמְחֶ֨ה אֶת־הָאָדָ֤ם מֵעַל֙ פְּנֵ֣י הָֽאֲדָמָ֔ה מֵֽאָדָם֙ עַד־בְּהֵמָ֔ה עַד־רֶ֖מֶשׂ וְעַד־עֹ֣וף הַשָּׁמָ֑יִם
# 653118
# אֶת־הָאָדָ֤ם
# אָדָ֤ם
#
# ('Genesis', 6, 10)
# וַיֹּ֥ולֶד נֹ֖חַ שְׁלֹשָׁ֣ה בָנִ֑ים אֶת־שֵׁ֖ם אֶת־חָ֥ם וְאֶת־יָֽפֶת׃
# 653144
# שְׁלֹשָׁ֣ה בָנִ֑ים אֶת־שֵׁ֖ם אֶת־חָ֥ם וְאֶת־יָֽפֶת׃
# שְׁלֹשָׁ֣ה
#
# ('Genesis', 6, 12)
# וַיַּ֧רְא אֱלֹהִ֛ים אֶת־הָאָ֖רֶץ
# 653156
# אֶת־הָאָ֖רֶץ
# אָ֖רֶץ

# %%
# for i, word in enumerate(F.lex.s('KL/')):
        
#     daughter = E.mother.t(word)
    
#     if F.otype.v(word) == 'lex':
#         continue
    
#     phrase = L.u(word, 'phrase')[0]
    
#     if F.function.v(phrase) not in {'Subj', 'Objc'}:
#         continue
    
#     heads = get_heads(phrase)
#     lemmas = list(F.lex.v(w) for w in L.d(phrase, 'word'))
    
#     if heads and len(heads) > 1 and lemmas.count('KL/') == 1:
                
#         print(T.sectionFromNode(word))
#         print(T.text(L.d(phrase, 'word')), phrase)
#         print(T.text(L.d(daughter[0], 'word')))
#         print('|'.join(T.text([n]) for n in heads))
#         print()
        
#     if i > 200:
#         break

# %%
tests = list()

for i, word in enumerate(F.lex.s('KL/')):
            
    if F.otype.v(word) == 'lex':
        continue
    
    phrase = L.u(word, 'phrase')[0]
    
    if F.function.v(phrase) not in {'Subj', 'Objc'}:
        continue
    
    subphrases = L.u(word, 'subphrase')
    
    for sp in subphrases:
        
        daughter = E.mother.t(sp)[0] if E.mother.t(sp) else None
        
        if not daughter:
            continue
        
        d_words = set(F.lex.v(w) for w in L.d(daughter, 'word'))
        
        if F.rela.v(daughter) == 'par' and not d_words & {'KL/'}:
            
            heads = get_heads(phrase)
            
            print(T.sectionFromNode(word))
            print(phrase, T.text(L.d(phrase, 'word')))
            print('sp: ', T.text(L.d(sp, 'word')))
            print('par: ', T.text(L.d(daughter, 'word')))
            print('|'.join(T.text([n]) for n in heads))
            print()
# Out:
# ('Genesis', 14, 7)
# 654976 אֶֽת־כָּל־שְׂדֵ֖ה הָעֲמָלֵקִ֑י וְגַם֙ אֶת־הָ֣אֱמֹרִ֔י
# sp:  אֶֽת־כָּל־שְׂדֵ֖ה הָעֲמָלֵקִ֑י
# par:  גַם֙ אֶת־הָ֣אֱמֹרִ֔י
# שְׂדֵ֖ה
#
# ('Genesis', 34, 29)
# 663207 אֶת־כָּל־חֵילָ֤ם וְאֶת־כָּל־טַפָּם֙ וְאֶת־נְשֵׁיהֶ֔ם
# sp:  אֶת־כָּל־חֵילָ֤ם וְאֶת־כָּל־טַפָּם֙
# par:  אֶת־נְשֵׁיהֶ֔ם
# חֵילָ֤ם |טַפָּם֙ |נְשֵׁיהֶ֔ם
#
# ('Genesis', 34, 29)
# 705149 אֹתֹ֛ו וְאֶת־כָּל־עַמֹּ֖ו וְאֶת־אַרְצֹ֑ו
# sp:  אֹתֹ֛ו וְאֶת־כָּל־עַמֹּ֖ו
# par:  אֶת־אַרְצֹ֑ו
# עַמֹּ֖ו |אַרְצֹ֑ו
#
# ('Deuteronomy', 3, 7)
# 705194 כָל־הַבְּהֵמָ֛ה וּשְׁלַ֥ל הֶעָרִ֖ים
# sp:  כָל־הַבְּהֵמָ֛ה
# par:  שְׁלַ֥ל הֶעָרִ֖ים
# בְּהֵמָ֛ה |שְׁלַ֥ל
#
# ('Deuteronomy', 5, 14)
# 706168 אַתָּ֣ה וּבִנְךָֽ־וּבִתֶּ֣ךָ וְעַבְדְּךָֽ־וַ֠אֲמָתֶךָ וְשֹׁורְךָ֨ וַחֲמֹֽרְךָ֜ וְכָל־בְּהֶמְתֶּ֗ךָ וְגֵֽרְךָ֙
# sp:  כָל־בְּהֶמְתֶּ֗ךָ
# par:  גֵֽרְךָ֙
#
#
# ('Deuteronomy', 11, 32)
# 708293 אֵ֥ת כָּל־הַֽחֻקִּ֖ים וְאֶת־הַמִּשְׁפָּטִ֑ים
# sp:  אֵ֥ת כָּל־הַֽחֻקִּ֖ים
# par:  אֶת־הַמִּשְׁפָּטִ֑ים
# חֻקִּ֖ים |מִּשְׁפָּטִ֑ים
#
# ('Deuteronomy', 17, 19)
# 710030 אֶֽת־כָּל־דִּבְרֵ֞י הַתֹּורָ֥ה הַזֹּ֛את וְאֶת־הַחֻקִּ֥ים הָאֵ֖לֶּה
# sp:  אֶֽת־כָּל־דִּבְרֵ֞י הַתֹּורָ֥ה הַזֹּ֛את
# par:  אֶת־הַחֻקִּ֥ים הָאֵ֖לֶּה
# דִּבְרֵ֞י |חֻקִּ֥ים
#
# ('Deuteronomy', 28, 42)
# 713346 כָּל־עֵצְךָ֖ וּפְרִ֣י אַדְמָתֶ֑ךָ
# sp:  כָּל־עֵצְךָ֖
# par:  פְרִ֣י אַדְמָתֶ֑ךָ
# עֵצְךָ֖ |פְרִ֣י
#
# ('Deuteronomy', 31, 28)
# 714713 אֶת־כָּל־זִקְנֵ֥י שִׁבְטֵיכֶ֖ם וְשֹׁטְרֵיכֶ֑ם
# sp:  כָּל־זִקְנֵ֥י שִׁבְטֵיכֶ֖ם
# par:  שֹׁטְרֵיכֶ֑ם
# זִקְנֵ֥י
#
# ('Deuteronomy', 34, 2)
# 715596 אֵת֙ כָּל־נַפְתָּלִ֔י וְאֶת־אֶ֥רֶץ אֶפְרַ֖יִם וּמְנַשֶּׁ֑ה וְאֵת֙ כָּל־אֶ֣רֶץ יְהוּדָ֔ה עַ֖ד הַיָּ֥ם הָאַחֲרֹֽון׃
# sp:  אֵת֙ כָּל־נַפְתָּלִ֔י
# par:  אֶת־אֶ֥רֶץ אֶפְרַ֖יִם וּמְנַשֶּׁ֑ה
#
#
# ('Joshua', 8, 33)
# 718309 כָל־יִשְׂרָאֵ֡ל וּזְקֵנָ֡יו וְשֹׁטְרִ֣ים׀ וְשֹׁפְטָ֡יו
# sp:  כָל־יִשְׂרָאֵ֡ל
# par:  זְקֵנָ֡יו
# יִשְׂרָאֵ֡ל
#
# ('Joshua', 10, 42)
# 719275 אֵ֨ת כָּל־הַמְּלָכִ֤ים הָאֵ֨לֶּה֙ וְאֶת־אַרְצָ֔ם
# sp:  אֵ֨ת כָּל־הַמְּלָכִ֤ים הָאֵ֨לֶּה֙
# par:  אֶת־אַרְצָ֔ם
# מְּלָכִ֤ים |אַרְצָ֔ם
#
# ('Joshua', 11, 16)
# 719475 אֶת־כָּל־הָאָ֣רֶץ הַזֹּ֗את הָהָ֤ר וְאֶת־כָּל־הַנֶּ֨גֶב֙ וְאֵת֙ כָּל־אֶ֣רֶץ הַגֹּ֔שֶׁן וְאֶת־הַשְּׁפֵלָ֖ה וְאֶת־הָעֲרָבָ֑ה וְאֶת־הַ֥ר יִשְׂרָאֵ֖ל וּשְׁפֵלָתֹֽה׃
# sp:  אֵת֙ כָּל־אֶ֣רֶץ הַגֹּ֔שֶׁן
# par:  אֶת־הַשְּׁפֵלָ֖ה
#
#
# ('Joshua', 21, 26)
# 721551 כָּל־עָרִ֥ים עֶ֖שֶׂר וּמִגְרְשֵׁיהֶ֑ן
# sp:  כָּל־עָרִ֥ים עֶ֖שֶׂר
# par:  מִגְרְשֵׁיהֶ֑ן
# עָרִ֥ים |מִגְרְשֵׁיהֶ֑ן
#
# ('Joshua', 24, 18)
# 722643 אֶת־כָּל־הָעַמִּ֗ים וְאֶת־הָאֱמֹרִ֛י
# sp:  אֶת־כָּל־הָעַמִּ֗ים
# par:  אֶת־הָאֱמֹרִ֛י
# עַמִּ֗ים
#
# ('Judges', 6, 33)
# 725106 כָל־מִדְיָ֧ן וַעֲמָלֵ֛ק וּבְנֵי־קֶ֖דֶם
# sp:  כָל־מִדְיָ֧ן
# par:  עֲמָלֵ֛ק
# מִדְיָ֧ן |עֲמָלֵ֛ק |בְנֵי־
#
# ('Judges', 6, 33)
# 725106 כָל־מִדְיָ֧ן וַעֲמָלֵ֛ק וּבְנֵי־קֶ֖דֶם
# sp:  כָל־מִדְיָ֧ן וַעֲמָלֵ֛ק
# par:  בְנֵי־קֶ֖דֶם
# מִדְיָ֧ן |עֲמָלֵ֛ק |בְנֵי־
#
# ('Judges', 9, 51)
# 726792 כָּל־הָאֲנָשִׁ֣ים וְהַנָּשִׁ֗ים וְכֹל֙ בַּעֲלֵ֣י הָעִ֔יר
# sp:  כָּל־הָאֲנָשִׁ֣ים
# par:  הַנָּשִׁ֗ים
# אֲנָשִׁ֣ים |נָּשִׁ֗ים |בַּעֲלֵ֣י
#
# ('1_Kings', 7, 5)
# 755997 כָל־הַפְּתָחִ֥ים וְהַמְּזוּזֹ֖ות
# sp:  כָל־הַפְּתָחִ֥ים
# par:  הַמְּזוּזֹ֖ות
# פְּתָחִ֥ים |מְּזוּזֹ֖ות
#
# ('1_Kings', 12, 21)
# 758828 אֶת־כָּל־בֵּ֨ית יְהוּדָ֜ה וְאֶת־שֵׁ֣בֶט בִּנְיָמִ֗ן
# sp:  אֶת־כָּל־בֵּ֨ית יְהוּדָ֜ה
# par:  אֶת־שֵׁ֣בֶט בִּנְיָמִ֗ן
# בֵּ֨ית |שֵׁ֣בֶט
#
# ('2_Kings', 24, 14)
# 773632 אֶת־כָּל־יְ֠רוּשָׁלִַם וְֽאֶת־כָּל־הַשָּׂרִ֞ים וְאֵ֣ת׀ כָּל־גִּבֹּורֵ֣י הַחַ֗יִל וְכָל־הֶחָרָ֖שׁ וְהַמַּסְגֵּ֑ר
# sp:  כָל־הֶחָרָ֖שׁ
# par:  הַמַּסְגֵּ֑ר
# חָרָ֖שׁ |מַּסְגֵּ֑ר
#
# ('Isaiah', 37, 18)
# 781785 אֶת־כָּל־הָאֲרָצֹ֖ות וְאֶת־אַרְצָֽם׃
# sp:  אֶת־כָּל־הָאֲרָצֹ֖ות
# par:  אֶת־אַרְצָֽם׃
# אֲרָצֹ֖ות |אַרְצָֽם׃
#
# ('Isaiah', 40, 4)
# 782432 כָל־הַ֥ר וְגִבְעָ֖ה
# sp:  כָל־הַ֥ר
# par:  גִבְעָ֖ה
# הַ֥ר |גִבְעָ֖ה
#
# ('Jeremiah', 38, 23)
# 801806 אֶת־כָּל־נָשֶׁ֣יךָ וְאֶת־בָּנֶ֗יךָ
# sp:  אֶת־כָּל־נָשֶׁ֣יךָ
# par:  אֶת־בָּנֶ֗יךָ
# נָשֶׁ֣יךָ |בָּנֶ֗יךָ
#
# ('Jeremiah', 49, 29)
# 804894 יְרִיעֹותֵיהֶ֧ם וְכָל־כְּלֵיהֶ֛ם וּגְמַלֵּיהֶ֖ם
# sp:  כָל־כְּלֵיהֶ֛ם
# par:  גְמַלֵּיהֶ֖ם
# יְרִיעֹותֵיהֶ֧ם |כְּלֵיהֶ֛ם |גְמַלֵּיהֶ֖ם
#
# ('Ezekiel', 10, 12)
# 809121 כָל־בְּשָׂרָם֙ וְגַבֵּהֶ֔ם וִֽידֵיהֶ֖ם וְכַנְפֵיהֶ֑ם וְהָאֹֽופַנִּ֗ים
# sp:  כָל־בְּשָׂרָם֙
# par:  גַבֵּהֶ֔ם
# בְּשָׂרָם֙ |גַבֵּהֶ֔ם |ידֵיהֶ֖ם |כַנְפֵיהֶ֑ם |אֹֽופַנִּ֗ים
#
# ('Ezekiel', 27, 9)
# 815282 כָּל־אֳנִיֹּ֨ות הַיָּ֤ם וּמַלָּֽחֵיהֶם֙
# sp:  כָּל־אֳנִיֹּ֨ות הַיָּ֤ם
# par:  מַלָּֽחֵיהֶם֙
# אֳנִיֹּ֨ות |מַלָּֽחֵיהֶם֙
#
# ('Ezekiel', 31, 16)
# 816564 כָּל־עֲצֵי־עֵ֔דֶן מִבְחַ֥ר וְטֹוב־לְבָנֹ֖ון כָּל־שֹׁ֥תֵי מָֽיִם׃
# sp:  כָּל־עֲצֵי־עֵ֔דֶן
# par:  מִבְחַ֥ר וְטֹוב־לְבָנֹ֖ון
# עֲצֵי־|מִבְחַ֥ר
#
# ('Ezekiel', 38, 6)
# 819034 גֹּ֚מֶר וְכָל־אֲגַפֶּ֔יהָ בֵּ֚ית תֹּֽוגַרְמָ֔ה יַרְכְּתֵ֥י צָפֹ֖ון וְאֶת־כָּל־אֲגַפָּ֑יו
# sp:  גֹּ֚מֶר וְכָל־אֲגַפֶּ֔יהָ
# par:  בֵּ֚ית תֹּֽוגַרְמָ֔ה
#
#
# ('Ezekiel', 38, 9)
# 819078 אַתָּה֙ וְכָל־אֲגַפֶּ֔יךָ וְעַמִּ֥ים רַבִּ֖ים אֹותָֽךְ׃ ס
# sp:  כָל־אֲגַפֶּ֔יךָ
# par:  עַמִּ֥ים רַבִּ֖ים
#
#
# ('Ezekiel', 39, 4)
# 819295 אַתָּה֙ וְכָל־אֲגַפֶּ֔יךָ וְעַמִּ֖ים
# sp:  אַתָּה֙ וְכָל־אֲגַפֶּ֔יךָ
# par:  עַמִּ֖ים
#
#
# ('Psalms', 65, 6)
# 842544 כָּל־קַצְוֵי־אֶ֝֗רֶץ וְיָ֣ם רְחֹקִֽים׃
# sp:  כָּל־קַצְוֵי־אֶ֝֗רֶץ
# par:  יָ֣ם רְחֹקִֽים׃
# קַצְוֵי־|יָ֣ם
#
# ('Esther', 4, 11)
# 874770 כָּל־עַבְדֵ֣י הַמֶּ֡לֶךְ וְעַם־מְדִינֹ֨ות הַמֶּ֜לֶךְ
# sp:  כָּל־עַבְדֵ֣י הַמֶּ֡לֶךְ
# par:  עַם־מְדִינֹ֨ות הַמֶּ֜לֶךְ
# עַבְדֵ֣י |עַם־
#
# ('Ezra', 10, 9)
# 883415 כָל־אַנְשֵֽׁי־יְהוּדָה֩ וּבִנְיָמִ֨ן׀
# sp:  כָל־אַנְשֵֽׁי־יְהוּדָה֩
# par:  בִנְיָמִ֨ן׀
# אַנְשֵֽׁי־|בִנְיָמִ֨ן׀
#
# ('Nehemiah', 7, 60)
# 885419 כָּל־הַ֨נְּתִינִ֔ים וּבְנֵ֖י עַבְדֵ֣י שְׁלֹמֹ֑ה
# sp:  כָּל־הַ֨נְּתִינִ֔ים
# par:  בְנֵ֖י עַבְדֵ֣י שְׁלֹמֹ֑ה
# נְּתִינִ֔ים |בְנֵ֖י
#
# ('Nehemiah', 10, 38)
# 886468 אֶת־רֵאשִׁ֣ית עֲרִיסֹתֵ֣ינוּ וּ֠תְרוּמֹתֵינוּ וּפְרִ֨י כָל־עֵ֜ץ תִּירֹ֣ושׁ וְיִצְהָ֗ר
# sp:  פְרִ֨י כָל־עֵ֜ץ
# par:  תִּירֹ֣ושׁ
# רֵאשִׁ֣ית
#
# ('2_Chronicles', 8, 6)
# 896523 אֵת֙ כָּל־עָרֵ֣י הָרֶ֔כֶב וְאֵ֖ת עָרֵ֣י הַפָּרָשִׁ֑ים וְאֵ֣ת׀ כָּל־חֵ֣שֶׁק שְׁלֹמֹ֗ה
# sp:  אֵת֙ כָּל־עָרֵ֣י הָרֶ֔כֶב
# par:  אֵ֖ת עָרֵ֣י הַפָּרָשִׁ֑ים
# עָרֵ֣י |עָרֵ֣י |חֵ֣שֶׁק
#
# ('2_Chronicles', 9, 14)
# 896835 כָל־מַלְכֵ֤י עֲרַב֙ וּפַחֹ֣ות הָאָ֔רֶץ
# sp:  כָל־מַלְכֵ֤י עֲרַב֙
# par:  פַחֹ֣ות הָאָ֔רֶץ
# מַלְכֵ֤י |פַחֹ֣ות
#
# ('2_Chronicles', 20, 18)
# 899529 כָל־יְהוּדָ֞ה וְיֹשְׁבֵ֣י יְרוּשָׁלִַ֗ם
# sp:  כָל־יְהוּדָ֞ה
# par:  יֹשְׁבֵ֣י יְרוּשָׁלִַ֗ם
# יְהוּדָ֞ה
#
# ('2_Chronicles', 20, 27)
# 899662 כָּל־אִ֨ישׁ יְהוּדָ֤ה וִֽירוּשָׁלִַ֨ם֙
# sp:  כָּל־אִ֨ישׁ יְהוּדָ֤ה
# par:  ירוּשָׁלִַ֨ם֙
# אִ֨ישׁ |ירוּשָׁלִַ֨ם֙
#
# ('2_Chronicles', 25, 24)
# 901202 כָֽל־הַזָּהָ֣ב וְהַכֶּ֡סֶף וְאֵ֣ת כָּל־הַ֠כֵּלִים וְאֶת־אֹצְרֹות֙ בֵּ֣ית הַמֶּ֔לֶךְ וְאֵ֖ת בְּנֵ֣י הַתַּֽעֲרֻבֹ֑ות
# sp:  כָֽל־הַזָּהָ֣ב
# par:  הַכֶּ֡סֶף
# זָּהָ֣ב |כֶּ֡סֶף
#
# ('2_Chronicles', 30, 25)
# 902676 כָּל־קְהַ֣ל יְהוּדָ֗ה וְהַכֹּהֲנִים֙ וְהַלְוִיִּ֔ם וְכָל־הַקָּהָ֖ל וְהַגֵּרִ֗ים
# sp:  כָּל־קְהַ֣ל יְהוּדָ֗ה
# par:  הַכֹּהֲנִים֙ וְהַלְוִיִּ֔ם
# קְהַ֣ל |כֹּהֲנִים֙ |קָּהָ֖ל |גֵּרִ֗ים
#
# ('2_Chronicles', 32, 4)
# 902962 אֶת־כָּל־הַמַּעְיָנֹ֔ות וְאֶת־הַנַּ֛חַל
# sp:  אֶת־כָּל־הַמַּעְיָנֹ֔ות
# par:  אֶת־הַנַּ֛חַל
# מַּעְיָנֹ֔ות |נַּ֛חַל
#
# ('2_Chronicles', 32, 33)
# 903349 כָּל־יְהוּדָ֖ה וְיֹשְׁבֵ֣י יְרוּשָׁלִָ֑ם
# sp:  כָּל־יְהוּדָ֖ה
# par:  יֹשְׁבֵ֣י יְרוּשָׁלִָ֑ם
# יְהוּדָ֖ה
#
# ('2_Chronicles', 34, 30)
# 904050 כָל־אִ֨ישׁ יְהוּדָ֜ה וְיֹשְׁבֵ֣י יְרוּשָׁלִַ֗ם וְהַכֹּֽהֲנִים֙ וְהַלְוִיִּ֔ם וְכָל־הָעָ֖ם
# sp:  כָל־אִ֨ישׁ יְהוּדָ֜ה
# par:  יֹשְׁבֵ֣י יְרוּשָׁלִַ֗ם
# אִ֨ישׁ |כֹּֽהֲנִים֙ |עָ֖ם
#
# ('2_Chronicles', 36, 14)
# 904565 גַּ֠ם כָּל־שָׂרֵ֨י הַכֹּהֲנִ֤ים וְהָעָם֙
# sp:  כָּל־שָׂרֵ֨י הַכֹּהֲנִ֤ים
# par:  הָעָם֙
# שָׂרֵ֨י |עָם֙
